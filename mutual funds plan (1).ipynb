# %% [markdown]
# # Creating a mutual fund plan with python

# %% [markdown]
# A mutual fund plan is created by selecting the stocks where an investor can benfit in the long term. Here is the process we can follow to create a mutual fund plan:
# STEP 1: Gather historical data, such as closing price and growth tends over time.
# STEP 2: calculate key metrics like return on investment(ROI) and volatility(risk) to understand how each stock has performed historically.
# STEP 3: choose stocks that have high ROI and low volatility to ensure a balance between risk and reward.
# STEP 4: calculate the future value of monthly investment based on the expected ROI of the selected stocks.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import plotly.graph_objs as go
import plotly.express as px

# %%
""" 
The plotly.graph_objs as go:
1.)gives fine grained control for building complex and highly customized visualizations.
2.)you build charts by manually defining data and layout.

The plotly.express as px:
1.)High level interface;great for quick and simple plots.
2.)Automatically handles axes, legends, coloring, etc.
"""
# Out:
# ' \nThe plotly.graph_objs as go:\n1.)gives fine grained control for building complex and highly customized visualizations.\n2.)you build charts by manually defining data and layout.\n\nThe plotly.express as px:\n1.)High level interface;great for quick and simple plots.\n2.)Automatically handles axes, legends, coloring, etc.\n'

# %%
data = pd.read_csv('nifty.csv')

# %%
data
# Out:
#                          Date  RELIANCE.NS  HDFCBANK.NS  ICICIBANK.NS  \
# 0   2024-08-20 00:00:00+05:30  2991.899902  1637.699951   1179.449951
# 1   2024-08-21 00:00:00+05:30  2997.350098  1625.800049   1174.849976
# 2   2024-08-22 00:00:00+05:30  2996.250000  1631.300049   1191.099976
# 3   2024-08-23 00:00:00+05:30  2999.949951  1625.050049   1203.500000
# 4   2024-08-26 00:00:00+05:30  3025.199951  1639.949951   1213.300049
# 5   2024-08-27 00:00:00+05:30  3000.899902  1637.750000   1226.349976
# 6   2024-08-28 00:00:00+05:30  2996.600098  1637.099976   1223.849976
# 7   2024-08-29 00:00:00+05:30  3041.850098  1638.550049   1221.900024
# 8   2024-08-30 00:00:00+05:30  3019.250000  1636.900024   1229.199951
# 9   2024-09-02 00:00:00+05:30  3032.500000  1626.949951   1229.949951
# 10  2024-09-03 00:00:00+05:30  3018.250000  1637.349976   1247.699951
# 11  2024-09-04 00:00:00+05:30  3029.100098  1641.800049   1236.349976
# ...

# %%
data.head()
# Out:
#                         Date  RELIANCE.NS  HDFCBANK.NS  ICICIBANK.NS  \
# 0  2024-08-20 00:00:00+05:30  2991.899902  1637.699951   1179.449951
# 1  2024-08-21 00:00:00+05:30  2997.350098  1625.800049   1174.849976
# 2  2024-08-22 00:00:00+05:30  2996.250000  1631.300049   1191.099976
# 3  2024-08-23 00:00:00+05:30  2999.949951  1625.050049   1203.500000
# 4  2024-08-26 00:00:00+05:30  3025.199951  1639.949951   1213.300049
#
#        INFY.NS       TCS.NS  KOTAKBANK.NS  HINDUNILVR.NS      ITC.NS  \
# 0  1872.199951  4523.299805   1805.650024    2751.050049  498.799988
# 1  1872.699951  4551.500000   1812.949951    2791.199951  505.399994
# 2  1880.250000  4502.000000   1821.500000    2792.800049  504.549988
# 3  1862.099976  4463.899902   1818.000000    2815.600098  505.799988
# 4  1876.150024  4502.450195   1812.500000    2821.149902  505.700012
#
#          LT.NS  ...  HEROMOTOCO.NS   DRREDDY.NS   SHREECEM.NS  BRITANNIA.NS  \
# ...

# %%
data['Date'] = pd.to_datetime(data['Date'])

# %%
data.isnull().sum()
# Out:
# Date              0
# RELIANCE.NS       0
# HDFCBANK.NS       0
# ICICIBANK.NS      0
# INFY.NS           0
# TCS.NS            0
# KOTAKBANK.NS      0
# HINDUNILVR.NS     0
# ITC.NS            0
# LT.NS             0
# SBIN.NS           0
# BAJFINANCE.NS     0
# BHARTIARTL.NS     0
# HCLTECH.NS        0
# ASIANPAINT.NS     0
# AXISBANK.NS       0
# DMART.NS          0
# MARUTI.NS         0
# ULTRACEMCO.NS     0
# HDFC.NS          24
# TITAN.NS          0
# SUNPHARMA.NS      0
# M&M.NS            0
# NESTLEIND.NS      0
# WIPRO.NS          0
# ADANIGREEN.NS     0
# TATASTEEL.NS      0
# JSWSTEEL.NS       0
# POWERGRID.NS      0
# ONGC.NS           0
# NTPC.NS           0
# COALINDIA.NS      0
# BPCL.NS           0
# IOC.NS            0
# TECHM.NS          0
# INDUSINDBK.NS     0
# DIVISLAB.NS       0
# GRASIM.NS         0
# CIPLA.NS          0
# BAJAJFINSV.NS     0
# TATAMOTORS.NS     0
# HEROMOTOCO.NS     0
# DRREDDY.NS        0
# SHREECEM.NS       0
# BRITANNIA.NS      0
# ...

# %%
# Here the HDFC.NS has no values so we dropped that column
data.drop(columns=['HDFC.NS'], inplace= True)

# %%
"""
1.)looping through each company column in the df, skipping the first column(assumed to be date)
2.)the whole block adds one line trace per company
3.)next block updates the layoutof the figure
"""

# %%
fig = go.Figure()

for company in data.columns[1:]:
    fig.add_trace(go.Scatter(x=data['Date'], y=data[company],
                             mode='lines',
                             name=company,
                             opacity=0.5))

fig.update_layout(
    title='Stock Price Trends of All Indian Companies',
    xaxis_title='Date',
    yaxis_title='Closing Price (INR)',
    xaxis=dict(tickangle=45), 
    legend=dict(
        x=1.05,
        y=1,
        traceorder="normal",
        font=dict(size=10),
        orientation="v"
    ),
    margin=dict(l=0, r=0, t=30, b=0),  
    hovermode='x',
    template='plotly_white'
)

fig.show()
# Out:
# <div>                            <div id="f3daa139-7a73-4f97-9cda-0a8663e547ed" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f3daa139-7a73-4f97-9cda-0a8663e547ed")) {                    Plotly.newPlot(                        "f3daa139-7a73-4f97-9cda-0a8663e547ed",                        [{"mode":"lines","name":"RELIANCE.NS","opacity":0.5,"x":["2024-08-20T00:00:00+05:30","2024-08-21T00:00:00+05:30","2024-08-22T00:00:00+05:30","2024-08-23T00:00:00+05:30","2024-08-26T00:00:00+05:30","2024-08-27T00:00:00+05:30","2024-08-28T00:00:00+05:30","2024-08-29T00:00:00+05:30","2024-08-30T00:00:00+05:30","2024-09-02T00:00:00+05:30","2024-09-03T00:00:00+05:30","2024-09-04T00:00:00+05:30","2024-09-05T00:00:00+05:30","2024-09-06T00:00:00+05:30","2024-09-09T00:00:0
# ...

# %%
#Now look at the companies with the highest risks for investing
#we pulled the standard deviation of the comapnies and we arranges in desc an dthe top are the high risk to invest

all_companies = data.columns[1:]

volatility_all_companies = data[all_companies].std()

volatility_all_companies.sort_values(ascending=False).head(10)
# Out:
# BAJAJ-AUTO.NS    659.810841
# SHREECEM.NS      429.919834
# BAJFINANCE.NS    306.658594
# DIVISLAB.NS      247.674895
# HEROMOTOCO.NS    247.092728
# DRREDDY.NS       175.124908
# ULTRACEMCO.NS    172.673053
# DMART.NS         155.593701
# BRITANNIA.NS     144.164343
# MARUTI.NS        109.587342
# dtype: float64

# %%
#Now we look for the highest growth rate for investing

growth_all_companies = data[all_companies].pct_change() * 100

average_growth_all_companies = growth_all_companies.mean()

average_growth_all_companies.sort_values(ascending=False).head(10)
# Out:
# BAJAJ-AUTO.NS    0.883421
# BAJAJFINSV.NS    0.791730
# BHARTIARTL.NS    0.735219
# DIVISLAB.NS      0.634851
# HEROMOTOCO.NS    0.602192
# ICICIBANK.NS     0.557742
# BAJFINANCE.NS    0.536819
# TITAN.NS         0.393800
# HINDUNILVR.NS    0.351634
# BRITANNIA.NS     0.327747
# dtype: float64

# %%
#Companies with the highest return on investment

initial_price_all = df[all_companies].iloc[0]
final_price_all = df[all_companies].iloc[-1]
roi_all_companies = ((final_price_all - initial_price_all)/ initial_price_all)*100
roi_all_companies.sort_values(ascending=False).head(10)
# Out:
# BAJAJ-AUTO.NS    22.107017
# BAJAJFINSV.NS    19.642973
# BHARTIARTL.NS    18.120965
# DIVISLAB.NS      15.404976
# HEROMOTOCO.NS    14.660402
# ICICIBANK.NS     13.480860
# BAJFINANCE.NS    12.797149
# TITAN.NS          9.275089
# HINDUNILVR.NS     8.235039
# BRITANNIA.NS      7.713587
# dtype: float64

# %% [markdown]
# Creating a mutual fund paln based on high ROI and low risk. The goal is to find compaines that offer a high ROI but with low volatility to minimize risk.
# Here are the steps we can follow:
# Step 1: Define ROI and volatility threshold - We set threshold for ROI and volatility to select companies that provide good returns with lower risk
# Step 2: Rank companies by ROI and volatility
# Step 3: Assign investment ratios - Allocate more investment to companies with higher ROI and lower volatility.

# %%
#Lets start by defining threshold and selecting companies that meet the criteria

roi_threshold = roi_all_companies.median()
volatility_threshold = volatility_all_companies.median()

selected_companies = roi_all_companies[(roi_all_companies > roi_threshold) & (volatility_all_companies < volatility_threshold)]

selected_companies.sort_values(ascending=False)
# Out:
# ICICIBANK.NS     13.480860
# INDUSINDBK.NS     7.159914
# JSWSTEEL.NS       7.021748
# AXISBANK.NS       6.592466
# HDFCBANK.NS       6.319839
# SUNPHARMA.NS      5.627425
# KOTAKBANK.NS      5.474481
# CIPLA.NS          4.850117
# NTPC.NS           4.356926
# dtype: float64

# %%
#to balance the investment between these comapnies, we can use an inverse volatility ratio fpr allocation. compaines with lower volatility will get a higher weight.

selected_volatility = volatility_all_companies[selected_comapnies.index]
inverse_volatility = 1 / selected_volatility

investment_ratios = (inverse_volatility/inverse_volatility.sum())*100
investment_ratios.sort_values(ascending=False).head(10)
# Out:
# NTPC.NS          28.076767
# JSWSTEEL.NS      15.998503
# AXISBANK.NS       9.223133
# HDFCBANK.NS       8.933035
# CIPLA.NS          8.478347
# KOTAKBANK.NS      7.664235
# INDUSINDBK.NS     7.443153
# SUNPHARMA.NS      7.255261
# ICICIBANK.NS      6.927566
# dtype: float64

# %%
"""
Analyzing the mutual fund plan:

we created a mutual fund plan for long term investments.
now lets analyze and compare our mutual fund plan by comparing it with the high performing companies in the stock market.
lets start by comparing the risk in our mutual fund with the risk in the high growth companies.
"""

# %%
top_growth_companies = average_growth_all_companies.sort_values(ascending=False).head(10)
risk_growth_rate_companies = volatility_all_companies[top_growth_companies.index]
risk_mutual_fund_companies = volatility_all_companies[selected_companies.index]

fig = go.Figure()

fig.add_trace(go.Bar(
    x=risk_mutual_fund_companies,
    y=risk_mutual_fund_companies.index,
    orientation = 'h', #horizontal bar
    name="mutual fund companies",
    marker=dict(color='blue')

))

fig.add_trace(go.Bar(
    x=risk_growth_rate_companies,
    y=risk_growth_rate_comapnies.index,
    orientation='h',
    name='growth rate comapnies',
    marker=dict(color='green'),
    opacity = 0.6
))

fig.update_layout(
    title='Risk Comparision: Mutual Funds Vs Growth Rate Companies',
    xaxis_title='volatility(SD)',
    yaxis_title='Companies',
    barmode='overlay',
    legend=dict(title='company type'),
    template='plotly_white'
)

fig.show()
# Out:
# <div>                            <div id="7b6eae1f-9cb8-447f-865a-20d1d74c6382" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7b6eae1f-9cb8-447f-865a-20d1d74c6382")) {                    Plotly.newPlot(                        "7b6eae1f-9cb8-447f-865a-20d1d74c6382",                        [{"marker":{"color":"blue"},"name":"mutual fund companies","orientation":"h","x":[28.25822015367946,36.43872611857753,32.93631766039582,27.36940801772213,34.792913496422976,15.778456135987565,8.990767156899544,33.91461765157589,29.773690681239415],"y":["HDFCBANK.NS","ICICIBANK.NS","KOTAKBANK.NS","AXISBANK.NS","SUNPHARMA.NS","JSWSTEEL.NS","NTPC.NS","INDUSINDBK.NS","CIPLA.NS"],"type":"bar"},{"marker":{"color":"green"},"name":"growth rate comapnies","opacity":0.6,"or
# ...

# %%
#Lets compare the ROI of the both groups as well

# %%
expected_roi_mutual_fund = roi_all_companies[selected_companies.index]

expected_roi_growth_companies = roi_all_companies[top_growth_companies.index]

fig = go.Figure()

fig.add_trace(go.Bar(
    y=expected_roi_mutual_fund.index,
    x=expected_roi_mutual_fund,
    orientation='h',  
    name='Mutual Fund Companies',
    marker=dict(color='blue')
))

fig.add_trace(go.Bar(
    y=expected_roi_growth_companies.index,
    x=expected_roi_growth_companies,
    orientation='h',  
    name='Growth Rate Companies',
    marker=dict(color='green'),
    opacity=0.7
))

fig.update_layout(
    title='Expected ROI Comparison: Mutual Fund vs Growth Rate Companies',
    xaxis_title='Expected ROI (%)',
    yaxis_title='Companies',
    barmode='overlay',  
    legend=dict(title='Company Type'),
    template='plotly_white'
)

fig.show()
# Out:
# <div>                            <div id="4771faaf-1d63-4db4-80b6-a042168a5efc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4771faaf-1d63-4db4-80b6-a042168a5efc")) {                    Plotly.newPlot(                        "4771faaf-1d63-4db4-80b6-a042168a5efc",                        [{"marker":{"color":"blue"},"name":"Mutual Fund Companies","orientation":"h","x":[6.319838986741093,13.480860280847114,5.474481447090753,6.592465753424658,5.62742524346509,7.021747987200831,4.3569260817307836,7.159914489806559,4.850116774625558],"y":["HDFCBANK.NS","ICICIBANK.NS","KOTAKBANK.NS","AXISBANK.NS","SUNPHARMA.NS","JSWSTEEL.NS","NTPC.NS","INDUSINDBK.NS","CIPLA.NS"],"type":"bar"},{"marker":{"color":"green"},"name":"Growth Rate Companies","opacity":0.7,"orie
# ...

# %%
#calculating expected returns

# %%
monthly_investment = 5000  # Monthly investment in INR
years = [1, 3, 5, 10]  # Investment periods (in years)
n = 12  # Number of times interest is compounded per year (monthly)

avg_roi = expected_roi_mutual_fund.mean() / 100  # Convert to decimal

def future_value(P, r, n, t):
    return P * (((1 + r/n)**(n*t) - 1) / (r/n)) * (1 + r/n)

future_values = [future_value(monthly_investment, avg_roi, n, t) for t in years]

fig = go.Figure()

fig.add_trace(go.Scatter(
    x=[str(year) + " year" for year in years],
    y=future_values,
    mode='lines+markers',
    line=dict(color='blue'),
    marker=dict(size=8),
    name='Future Value'
))

fig.update_layout(
    title="Expected Value of Investments of ₹ 5000 Per Month (Mutual Funds)",
    xaxis_title="Investment Period",
    yaxis_title="Future Value (INR)",
    xaxis=dict(showgrid=True, gridcolor='lightgrey'),
    yaxis=dict(showgrid=True, gridcolor='lightgrey'),
    template="plotly_white",
    hovermode='x'
)

fig.show()
# Out:
# <div>                            <div id="80ce2d25-8218-4477-a475-ea035b52f8d0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("80ce2d25-8218-4477-a475-ea035b52f8d0")) {                    Plotly.newPlot(                        "80ce2d25-8218-4477-a475-ea035b52f8d0",                        [{"line":{"color":"blue"},"marker":{"size":8},"mode":"lines+markers","name":"Future Value","x":["1 year","3 year","5 year","10 year"],"y":[62244.67345712617,200068.58713430515,357800.088736709,859131.7041113974],"type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"col
# ...

# %% [markdown]
# So, this is how a mutual fund plan is designed by investment companies for long-term investors. Mutual funds are investment plans that pool money from multiple investors to purchase a diversified portfolio of stocks, bonds, and other securities, managed by professional fund managers.
